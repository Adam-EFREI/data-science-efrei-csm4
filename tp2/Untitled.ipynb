# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/home/adam/.local/lib/python3.10/site-packages/pandas/__init__.py'>

# %%
ds = pd.read_csv('../data/spam_train.csv', delimiter=';')

# %%
ds
# Out:
#      IsSpam  word_freq_make  word_freq_address  word_freq_all  word_freq_3d
# 0        No            0.00               0.00           0.00           0.0  \
# 1        No            0.00               0.00           0.00           0.0
# 2       Yes            0.00               0.00           0.00           0.0
# 3        No            0.00               0.00           0.00           0.0
# 4        No            0.00               0.00           1.33           0.0
# ...     ...             ...                ...            ...           ...
# 2967    Yes            0.00               0.00           0.00           0.0
# 2968     No            0.09               0.00           0.27           0.0
# 2969     No            0.00               0.67           0.33           0.0
# 2970    Yes            0.00               0.00           0.00           0.0
# 2971    Yes            0.00               0.00           0.00           0.0
#
# ...

# %%
ds.head()
# Out:
#   IsSpam  word_freq_make  word_freq_address  word_freq_all  word_freq_3d
# 0     No             0.0                0.0           0.00           0.0  \
# 1     No             0.0                0.0           0.00           0.0
# 2    Yes             0.0                0.0           0.00           0.0
# 3     No             0.0                0.0           0.00           0.0
# 4     No             0.0                0.0           1.33           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet
# 0           0.19             0.0               0.0                 0.0  \
# 1           0.00             0.0               0.0                 0.0
# 2           0.00             0.0               0.0                 0.0
# 3           0.00             0.0               0.0                 0.0
# 4           0.00             0.0               0.0                 0.0
#
#    word_freq_order  ...  word_freq_conference  char_freq_1  char_freq_2
# ...

# %%
ds.shape
# Out:
# (2972, 58)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(ds.drop('IsSpam', axis=1), 
                                                    ds['IsSpam'], 
                                                    test_size=0.2)

# %%
X_train
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d
# 206             0.00               0.00           0.00           0.0  \
# 2932            0.00               0.00           0.47           0.0
# 2214            0.00               0.00           0.00           0.0
# 1710            0.00               0.00           0.00           0.0
# 472             0.00               0.53           0.53           0.0
# ...              ...                ...            ...           ...
# 931             0.30               0.00           1.23           0.0
# 1517            0.35               0.46           0.31           0.0
# 1255            0.39               0.00           0.39           0.0
# 342             0.00               0.00           0.00           0.0
# 466             0.00               0.00           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet
# ...

# %%
y_test
# Out:
# 2728    Yes
# 1547     No
# 61       No
# 1257     No
# 2867     No
#        ...
# 669      No
# 2874    Yes
# 2155    Yes
# 2264    Yes
# 1018     No
# Name: IsSpam, Length: 595, dtype: object

# %%
logistic_regression = LogisticRegression(solver='lbfgs', max_iter=10000)
logistic_regression.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
logistic_regression
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred = logistic_regression.predict(X_test)

# %%
    accuracy = logistic_regression.score(X_test, y_test)

# %%
accuracy
# Out:
# 0.9411764705882353

# %%
ds
# Out:
#      IsSpam  word_freq_make  word_freq_address  word_freq_all  word_freq_3d
# 0        No            0.00               0.00           0.00           0.0  \
# 1        No            0.00               0.00           0.00           0.0
# 2       Yes            0.00               0.00           0.00           0.0
# 3        No            0.00               0.00           0.00           0.0
# 4        No            0.00               0.00           1.33           0.0
# ...     ...             ...                ...            ...           ...
# 2967    Yes            0.00               0.00           0.00           0.0
# 2968     No            0.09               0.00           0.27           0.0
# 2969     No            0.00               0.67           0.33           0.0
# 2970    Yes            0.00               0.00           0.00           0.0
# 2971    Yes            0.00               0.00           0.00           0.0
#
# ...

# %%
ds['IsSpam']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 2967    Yes
# 2968     No
# 2969     No
# 2970    Yes
# 2971    Yes
# Name: IsSpam, Length: 2972, dtype: object

# %%
ds['IsSpam'].replace({'No': 0})
# Out:
# 0         0
# 1         0
# 2       Yes
# 3         0
# 4         0
#        ...
# 2967    Yes
# 2968      0
# 2969      0
# 2970    Yes
# 2971    Yes
# Name: IsSpam, Length: 2972, dtype: object

# %%
ds
# Out:
#      IsSpam  word_freq_make  word_freq_address  word_freq_all  word_freq_3d
# 0        No            0.00               0.00           0.00           0.0  \
# 1        No            0.00               0.00           0.00           0.0
# 2       Yes            0.00               0.00           0.00           0.0
# 3        No            0.00               0.00           0.00           0.0
# 4        No            0.00               0.00           1.33           0.0
# ...     ...             ...                ...            ...           ...
# 2967    Yes            0.00               0.00           0.00           0.0
# 2968     No            0.09               0.00           0.27           0.0
# 2969     No            0.00               0.67           0.33           0.0
# 2970    Yes            0.00               0.00           0.00           0.0
# 2971    Yes            0.00               0.00           0.00           0.0
#
# ...

# %%
ds = ds.replace({'No': 0})

# %%
ds
# Out:
#      IsSpam  word_freq_make  word_freq_address  word_freq_all  word_freq_3d
# 0         0            0.00               0.00           0.00           0.0  \
# 1         0            0.00               0.00           0.00           0.0
# 2       Yes            0.00               0.00           0.00           0.0
# 3         0            0.00               0.00           0.00           0.0
# 4         0            0.00               0.00           1.33           0.0
# ...     ...             ...                ...            ...           ...
# 2967    Yes            0.00               0.00           0.00           0.0
# 2968      0            0.09               0.00           0.27           0.0
# 2969      0            0.00               0.67           0.33           0.0
# 2970    Yes            0.00               0.00           0.00           0.0
# 2971    Yes            0.00               0.00           0.00           0.0
#
# ...
